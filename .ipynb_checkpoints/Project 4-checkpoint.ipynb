# %% [markdown]
# # Projet 4 - Analysez les ventes de votre entreprise

# %% [markdown]
# Nous allons étudier les ventes de livres en ligne de la société.
#
# Pour se faire nous allons tout d'abord nettoyer les données provenant de la base de donnée, ensuite les analyser pour en tirer les informations pertinentes, et enfin vérifier les corrélations suivantes :
#
# * Y a-t-il une corrélation entre le sexe des clients et les catégories de produits achetés ?
# * Y a-t-il une corrélation entre l'âge des clients et :
#     * Le montant total des achats ;
#     * La fréquence d’achat (ie. nombre d'achats par mois par exemple) ;
#     * La taille du panier moyen (en nombre d’articles) ;
#     * Les catégories de produits achetés.

# %% [markdown]
# ## Table des matières

# %% [markdown]
# 1. __Importation des données__
#
#
# 2. __Vérification de données manquantes__
#
#     1. Fichier customers
#     2. Fichier products
#     3. Fichier transactions
#
#
#
# 3. __Nettoyage des fichiers__
#
#     1. Nettoyage des données de test
#     2. Mise au format Datetime de la colonne date
#     3. Suppression des semaines sans vente de livres de categ 1
#
#
# 4. __Préparation du dataFrame de travail__
#
#     1. Assemblage des 3 fichiers en 1 seul
#     2. Création de nouvelles colonnes
#     3. Test Unitaire
#
#
# 5. __Visualisations des données__
#
#     1. Colonne birth, age, cat_age et sexe
#     2. Colonne price, cat_price et categ
#     3. Colonne date, weekday, daytime, month, week, year
#     4. Colonne session_amount, session_nb_produit et session_categ
#     5. Conclusion
#
#
# 6. __Analyses des données__
#
#     1. Produits les plus vendus
#     2. Les meilleurs clients

# %% [markdown]
# ## 1. Importation des données

# %% [markdown]
# Dans un premier temps, nous allons importer les données

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(color_codes = True)

# %%
customers = pd.read_csv('./Dataset/customers.csv')
products = pd.read_csv('./Dataset/products.csv')
transactions = pd.read_csv('./Dataset/transactions.csv', parse_dates=[1])

# %% [markdown]
# Nous allons, maintenant, regarder les dataFrames pour remarquer les valeurs manquantes

# %% [markdown]
# ## 2. Vérification de données manquantes

# %% [markdown]
# ### A. Fichier customers

# %%
customers.isnull().sum()
# Out:
# client_id    0
# sex          0
# birth        0
# dtype: int64

# %%
customers.describe()
# Out:
#              birth
# count  8623.000000
# mean   1978.280877
# std      16.919535
# min    1929.000000
# 25%    1966.000000
# 50%    1979.000000
# 75%    1992.000000
# max    2004.000000

# %%
customers['birth'].value_counts()
# Out:
# 2004    440
# 1979    215
# 1988    207
# 1986    203
# 1978    199
#        ...
# 1935      8
# 1932      6
# 1931      4
# 1930      4
# 1929      3
# Name: birth, Length: 76, dtype: int64

# %%
sns.distplot(customers['birth'], kde=False, bins=76)

# %% [markdown]
# Nous avons, ici, pour les années de naissances, environ 5% des clients qui sont nés en 2004. Est-ce un erreur ou une particularité à relever du site, qui cible les adolescents. Est-ce que dans l'inscription en ligne, cette année comprends les clients nés en 2004 et avant ?
#
# Le reste du dataFrame ne présente pas de valeurs manquantes ou erronées

# %% [markdown]
# ### B. Fichier products

# %%
products.isnull().sum()
# Out:
# id_prod    0
# price      0
# categ      0
# dtype: int64

# %%
products.describe()
# Out:
#              price        categ
# count  3287.000000  3287.000000
# mean     21.856641     0.370246
# std      29.847908     0.615387
# min      -1.000000     0.000000
# 25%       6.990000     0.000000
# 50%      13.060000     0.000000
# 75%      22.990000     1.000000
# max     300.000000     2.000000

# %%
products['price'].value_counts()
# Out:
# 4.99     85
# 6.99     84
# 3.99     80
# 5.99     78
# 8.99     74
#          ..
# 4.13      1
# 2.84      1
# 13.13     1
# 18.77     1
# 9.00      1
# Name: price, Length: 1455, dtype: int64

# %%
products['categ'].value_counts()
# Out:
# 0    2309
# 1     739
# 2     239
# Name: categ, dtype: int64

# %%
products.nsmallest(10, 'price')
# Out:
#      id_prod  price  categ
# 731      T_0  -1.00      0
# 2272   0_528   0.62      0
# 2355   0_202   0.62      0
# 370    0_120   0.66      0
# 1211  0_1844   0.77      0
# 1530  0_1620   0.80      0
# 2302  0_1364   0.81      0
# 2425   0_612   0.88      0
# 2772   0_902   0.92      0
# 686   0_2138   0.93      0

# %%
products.nlargest(10, 'price')
# Out:
#      id_prod   price  categ
# 947      2_2  300.00      2
# 724     2_76  254.44      2
# 394    2_158  247.22      2
# 1436   2_167  236.99      2
# 2779    2_30  233.54      2
# 1960   2_125  231.99      2
# 2487   2_166  230.04      2
# 786     2_40  228.11      2
# 10     2_228  225.17      2
# 1896     2_4  222.97      2

# %% [markdown]
# Nous remarquons qu'un produit à une valeur de -1, est-ce qu'il correspond à une valeur test, comme le 'T' dans son identifiant le laisse présager ?
#
# Le reste du dataFrame ne présente pas de valeurs manquantes ou erronées.

# %% [markdown]
# ### C. Fichier transactions

# %%
transactions.isnull().sum()
# Out:
# id_prod       0
# date          0
# session_id    0
# client_id     0
# dtype: int64

# %%
transactions.describe()
# Out:
#        id_prod                             date session_id client_id
# count   337016                           337016     337016    337016
# unique    3266                           336855     169195      8602
# top      1_369  test_2021-03-01 02:30:02.237413        s_0    c_1609
# freq      1081                               13        200     12855

# %% [markdown]
# Nous constatons que certains articles n'ont pas été vendu, nous avons 3266 produits uniques de vendu sur un total de 3287 produits référencés. De plus, nous avons certains clients qui n'ont éffectués aucun achat, nous avons, dans le dataframe transaction 8502 clients uniques alors qu'il y a 8623 clients d'enregistrés.

# %% [markdown]
# Nous avons dans la colonne date une valeur test : test_2021-03-01 02:30:02.237413

# %% [markdown]
# ## 3. Nettoyage des fichiers

# %% [markdown]
# ### A. Nettoyage des données de test

# %% [markdown]
# Tout d'abord, nous allons enlever les données de test rentrées dans les dataFrames.

# %%
transactions[transactions['date'].str.contains('test')]
# Out:
#        id_prod                             date session_id client_id
# 1431       T_0  test_2021-03-01 02:30:02.237420        s_0      ct_1
# 2365       T_0  test_2021-03-01 02:30:02.237446        s_0      ct_1
# 2895       T_0  test_2021-03-01 02:30:02.237414        s_0      ct_1
# 5955       T_0  test_2021-03-01 02:30:02.237441        s_0      ct_0
# 7283       T_0  test_2021-03-01 02:30:02.237434        s_0      ct_1
# ...        ...                              ...        ...       ...
# 332594     T_0  test_2021-03-01 02:30:02.237445        s_0      ct_0
# 332705     T_0  test_2021-03-01 02:30:02.237423        s_0      ct_1
# 332730     T_0  test_2021-03-01 02:30:02.237421        s_0      ct_1
# 333442     T_0  test_2021-03-01 02:30:02.237431        s_0      ct_1
# 335279     T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
#
# [200 rows x 4 columns]

# %% [markdown]
# Nous remarquons que les tests ont été fait avec d'autres éléments prédéfinis. Nous allons rechercher ces éléments pour les enlever de nos dataFrames pour éviter de fausser notre analyse.

# %%
transactions.loc[transactions['date'].str.contains('test')].describe()
# Out:
#        id_prod                             date session_id client_id
# count      200                              200        200       200
# unique       1                               39          1         2
# top        T_0  test_2021-03-01 02:30:02.237413        s_0      ct_0
# freq       200                               13        200       106

# %% [markdown]
# Nous remarquons que nous avons un produit unique (T_0), une session unique (s_0), et deux clients uniques (ct_0 et ct_1). Nous allons enlever ces éléments après vérification

# %%
transactions.loc[transactions['id_prod'] == 'T_0'].describe()
# Out:
#        id_prod                             date session_id client_id
# count      200                              200        200       200
# unique       1                               39          1         2
# top        T_0  test_2021-03-01 02:30:02.237413        s_0      ct_0
# freq       200                               13        200       106

# %% [markdown]
# Le client T_0 n'a été utilisé que pour les tests

# %%
transactions.loc[transactions['session_id'] == 's_0'].describe()
# Out:
#        id_prod                             date session_id client_id
# count      200                              200        200       200
# unique       1                               39          1         2
# top        T_0  test_2021-03-01 02:30:02.237413        s_0      ct_0
# freq       200                               13        200       106

# %% [markdown]
# De même, la session s_0 n'a été utilisé que pour les tests

# %%
transactions.loc[transactions['client_id'] == 'ct_0'].describe()
# Out:
#        id_prod                             date session_id client_id
# count      106                              106        106       106
# unique       1                               37          1         1
# top        T_0  test_2021-03-01 02:30:02.237413        s_0      ct_0
# freq       106                                9        106       106

# %%
transactions.loc[transactions['client_id'] == 'ct_1'].describe()
# Out:
#        id_prod                             date session_id client_id
# count       94                               94         94        94
# unique       1                               37          1         1
# top        T_0  test_2021-03-01 02:30:02.237443        s_0      ct_1
# freq        94                                5         94        94

# %% [markdown]
# Pour finir, les clients ct_0 et ct_1 ont été également utilisé que pour les tests.

# %% [markdown]
# Nous allons supprimer les 200 lignes contenant des dates de test

# %%
transactions = transactions[~transactions['date'].str.contains('test')]

# %% [markdown]
# Nous allons effacer le produit test T_0, d'une valeur négative, de la dataFrame products

# %%
products = products[~(products['id_prod'] == 'T_0')]

# %% [markdown]
# Nous allons effacer les clients ct_0 et ct_1 de la dataFrame customers

# %%
customers[customers['client_id'].str.contains('ct_')].describe()
# Out:
#         birth
# count     2.0
# mean   2001.0
# std       0.0
# min    2001.0
# 25%    2001.0
# 50%    2001.0
# 75%    2001.0
# max    2001.0

# %% [markdown]
# Nous n'avons que deux clients possèdant le préfixe 'ct', les clients tests, que nous allons enlever du dataFrame

# %%
customers = customers[~customers['client_id'].str.contains('ct_')]

# %% [markdown]
# Nous allons convertir la colonne date du dataFrame transactions en valeur de type datetime64

# %% [markdown]
# ### B. Mise au format Datetime de la colonne *date*

# %%
transactions['date'] = pd.to_datetime(transactions['date'])

# %%
transactions['date'].hist(bins = 12)

# %% [markdown]
# Nous constatons que les dates s'étalent sur 1 an de Mars 2021 à Mars 2022.

# %% [markdown]
# ### C. Suppression des semaines sans vente de livres de categ 1

# %% [markdown]
# Nous avons vu durant l'analyse de données que la vente de livres de categ fut nulle durant les semaines 40 à 42, et eu un volume plus faible durant les semaines 39 et 43. Ainsi, pour garder un data Frame homogène, nous avons allons enlever ses 5 semaines, afin de ne pas fausser les valeurs des corrélations. Voir le paragraphes 6.A

# %% [markdown]
# Nous allons faire une copie de la database et enlever les semaines 39 à 43 pendant la préparation du Data Frame

# %% [markdown]
# ## 4. Préparation du dataFrame de travail

# %% [markdown]
# ### A. Assemblage des 3 fichiers en 1 seul

# %% [markdown]
# Nous allons merger les 3 dataFrames en 1 seul pour faciliter l'analyse des données

# %%
df_transactions = transactions.merge(customers, how = 'inner', on = 'client_id')

# %%
df_transactions = df_transactions.merge(products, how = 'inner', on= 'id_prod')

# %%
df_transactions.describe()
# Out:
#                birth          price          categ
# count  336713.000000  336713.000000  336713.000000
# mean     1977.823568      17.215189       0.430156
# std        13.524433      17.855445       0.591082
# min      1929.000000       0.620000       0.000000
# 25%      1971.000000       8.610000       0.000000
# 50%      1980.000000      13.900000       0.000000
# 75%      1987.000000      18.990000       1.000000
# max      2004.000000     300.000000       2.000000

# %% [markdown]
# Nous utilisons des *inner joints* pour éviter l'ajout de valeur nulle dans notre dataFrame. Nous avons des clients et des produits qui n'ont jamais été vendus, mais également, des commandes sans produit ou client référencés

# %% [markdown]
# ### B. Création de nouvelles colonnes

# %% [markdown]
# Maintenant, nous allons rajouter les colonnes 'age', 'cat_age', 'cat_price', 'weekday', 'daytime', 'month', 'week', et 'year'. Ensuite, nous allons calculer les colonnes suivantes 'session_amount', 'session_nb_produit', 'session_categ' pour regrouper dans chaque lignes les informations des sessions.

# %%
df_transactions['age'] = df_transactions['date'].dt.year - df_transactions['birth']

# %% [markdown]
# Au vue de la répartion des ages vue dans la partie 5.A sur l'analyse des ages, nous allons créer 3 catégorie d'age ; de 18 à 29 ans, de 30 à 59 ans et de 60 à 90 ans

# %%
df_transactions['cat_age'] = pd.cut(x = df_transactions['age'], bins = [0, 29, 59, 99], labels = [1, 2, 3])

# %% [markdown]
# Au vue de la répartiton des prix vue dans la partie 5.B sur l'analyse des prix, nous allons créer 3 catégorie d'age ; de 0 à 4.99, de 5 à 19.99 et de 20 à 300.

# %%
df_transactions['cat_price'] = pd.cut(x = df_transactions['price'], bins = [0, 4.99, 19.99, 300], labels = [1, 2, 3])

# %%
df_transactions['weekday'] = df_transactions['date'].dt.dayofweek

# %%
df_transactions['daytime'] = df_transactions['date'].dt.hour

# %%
df_transactions['month'] = df_transactions['date'].dt.month

# %%
df_transactions['week'] = df_transactions['date'].dt.week

# %%
df_transactions['year'] = df_transactions['date'].dt.year

# %% [markdown]
# Nous allons supprimer les semaines 39 à 43 :

# %%
df_transactions_old = df_transactions.copy()
df_transactions = df_transactions[~df_transactions['week'].between(39,43)]

# %% [markdown]
# Nous allons créer les colonnes des données des sessions : le montant de la session, le nombre de produit par session et la moyenne des *categ* de la session

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('session_id')['price'].sum().reset_index(name = 'session_amount'), how='left', on='session_id')

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('session_id')['id_prod'].count().reset_index(name = 'session_nb_produit'), how='left', on='session_id')

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('session_id')['categ'].mean().reset_index(name = 'session_categ'), how='left', on='session_id')

# %% [markdown]
# Nous allons créer les colonnes des habitudes d'achats des clients : le nombre de session d'achat fait par le client, les catégories du nombre de session d'achat des clients par quartile, le nombre de livre acheté par le client, le montant total d'achat, rang du client en fonction de ses achats, la taille moyenne de son panier, la moyenne *categ*, fréquence d'achat par mois, l'achat moyen par session

# %%
df_client = df_transactions.drop_duplicates('session_id').groupby('client_id')

# %%
df_transactions = df_transactions.merge(df_client.count()['id_prod'].reset_index(name = 'nombre_achat_client'), how='left', on='client_id')

# %%
df_transactions['cat_nb_achat'] = pd.cut(x = df_transactions['nombre_achat_client'], bins = [0, df_transactions.quantile(0.25)['nombre_achat_client'], df_transactions.quantile(0.5)['nombre_achat_client'], df_transactions.quantile(0.75)['nombre_achat_client'], df_transactions.quantile(1)['nombre_achat_client']], labels = [1, 2, 3, 4])

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('client_id').count()['id_prod'].reset_index(name = 'nombre_livre_client'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(df_client.sum()['session_amount'].reset_index(name = 'montant_total'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(df_client.sum()['session_amount'].rank(ascending = False).reset_index(name = 'rang'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(df_client.mean()['session_nb_produit'].reset_index(name = 'session_nb_produit_mean'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(df_client.mean()['categ'].reset_index(name = 'categ_mean'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(((df_transactions.drop_duplicates('session_id').groupby(['month', 'client_id', ]).count()['price']).unstack().fillna(0).sum()/12).reset_index(name = 'freq_achat_mean'), how='left', on='client_id')

# %%
df_transactions = df_transactions.merge(df_client.mean()['session_amount'].reset_index(name = 'session_amount_mean'), how='left', on='client_id')

# %% [markdown]
# Nous allons créer les colonnes pour les livres : le rang du livre en terme de ventes, le nombre d'achat et le montant total

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('id_prod').count()['price'].reset_index(name = 'book_total_sold'), how='left', on='id_prod')

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('id_prod').count()['price'].rank(ascending = False).reset_index(name = 'book_rank_sold'), how='left', on='id_prod')

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('id_prod').sum()['price'].reset_index(name = 'book_total_price'), how='left', on='id_prod')

# %%
df_transactions = df_transactions.merge(df_transactions.groupby('id_prod').sum()['price'].rank(ascending = False).reset_index(name = 'book_rank_price'), how='left', on='id_prod')

# %% [markdown]
# ### C. Test Unitaire

# %%
df_transactions[df_transactions['session_id'] == 's_10146']
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 356      1_596 2021-03-23 02:04:33.255471    s_10146    c_1609   m   1980
# 27309   0_1531 2021-03-23 01:24:23.364443    s_10146    c_1609   m   1980
# 39074   0_1625 2021-03-23 01:54:07.379708    s_10146    c_1609   m   1980
# 106901  0_2178 2021-03-23 01:48:54.440912    s_10146    c_1609   m   1980
# 204027  0_1097 2021-03-23 01:22:08.479945    s_10146    c_1609   m   1980
# 272214   0_992 2021-03-23 01:50:53.119885    s_10146    c_1609   m   1980
#
#         price  categ  age cat_age  ... montant_total  rang  \
# 356     11.12      1   41       2  ...     148351.06   1.0
# 27309    6.99      0   41       2  ...     148351.06   1.0
# 39074    5.99      0   41       2  ...     148351.06   1.0
# 106901   9.22      0   41       2  ...     148351.06   1.0
# 204027  11.99      0   41       2  ...     148351.06   1.0
# 272214   8.58      0   41       2  ...     148351.06   1.0
#
# ...

# %% [markdown]
# Nous testons, pour une sessions, si les valeurs calculer sont correctes. Nous avons bien 6 produits, ayant une moyenne de 1/6 pour *session_categ* avec un montant de 53.89 qui est la somme des produits de la session.

# %% [markdown]
# ## 5. Visualisations des données

# %% [markdown]
# Nous allons visualiser les données de chaque colonnes pour avoir une vue global du comportements des acheteurs et du DataSet

# %%
df_transactions.describe()
# Out:
#                birth          price          categ            age  \
# count  310090.000000  310090.000000  310090.000000  310090.000000
# mean     1977.759247      17.430726       0.449476      43.430591
# std        13.624012      17.936220       0.593811      13.631829
# min      1929.000000       0.620000       0.000000      17.000000
# 25%      1970.000000       8.990000       0.000000      34.000000
# 50%      1980.000000      13.990000       0.000000      42.000000
# 75%      1987.000000      19.080000       1.000000      51.000000
# max      2004.000000     300.000000       2.000000      93.000000
#
#              weekday        daytime          month           week  \
# count  310090.000000  310090.000000  310090.000000  310090.000000
# mean        2.995047      11.514338       6.196388      25.049392
# std         2.003414       6.919547       3.522366      15.361373
# min         0.000000       0.000000       1.000000       1.000000
# ...

# %% [markdown]
# ### A. Colonne *birth*, *age*, *cat-age* et *sexe*

# %% [markdown]
# #### DataFrame avec tous les clients

# %% [markdown]
# Nous allons commencer par les colonnes *birth* et *age*. Nous avons l'age maximum à 93 ans et minimum à 17 ans, soit 76 ans. Pour *birth*, nous avons de 1929 à 2004, soit 75 ans. La différence entre *birth* et *age*, *birth* ne change pas pour un client donné, alors que *age* dépends de la date d'achat.

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions['birth'], axlabel='Birth - Transaction', kde=False, bins=76, ax=axes[0, 0])
sns.distplot(df_transactions['age'], axlabel='Age - Transaction', kde=False, bins=76, ax=axes[0, 1])
sns.distplot(df_transactions.drop_duplicates('session_id')['birth'], axlabel='Birth - Transaction unique', kde=False, bins=76, ax=axes[1, 0])
sns.distplot(df_transactions.drop_duplicates('session_id')['age'], axlabel='Age - Transaction unique', kde=False, bins=76, ax=axes[1, 1])

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.distplot(df_transactions['cat_age'], axlabel='Cat_age - Transaction', kde=False, bins=3, ax=axes[0])
sns.distplot(df_transactions.drop_duplicates('session_id')['cat_age'], axlabel='Cat_age - Transaction Unique', kde=False, bins=3, ax=axes[1])

# %% [markdown]
# Nous remarquons deux choses, premièrement, il a un nombre très important d'achat pour l'age de 41 ans (1980), qui n'existait pas dans la table *customers*. Deuxièmenent, nous remarquons toujours la présence d'un pic pour les personnes nées en 2004.
#
# Nous remarquons, que le nombre de sessions uniques n'influence pas notre répartition des âges. Ce qui veut dire que nous avons un ou des très bons clients dans cette tranche d'âge.

# %%
df = df_transactions[df_transactions['nombre_achat_client']  == 1].drop_duplicates('session_id').groupby('cat_age')['client_id'].count() / df_transactions.drop_duplicates('client_id').groupby('cat_age')['client_id'].count()

fig, axes = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x=df.index, y=df.values)

# %% [markdown]
# Nous voyons que les clients de moins de 30 ans sont ceux qui reviennent moins sur le site, mais dans des proportions très faible.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(df_transactions['sex'], ax=axes[0])
sns.countplot(df_transactions.drop_duplicates('session_id')['sex'], ax=axes[1])

# %% [markdown]
# Nous voyons qu'il y a autant d'homme que de femme qui achete sur le site.

# %%
df_transactions[['client_id', 'birth', 'sex', 'nombre_livre_client', 'montant_total']].drop_duplicates(['client_id']).nlargest(10, 'nombre_livre_client')
# Out:
#      client_id  birth sex  nombre_livre_client  montant_total
# 3       c_1609   1980   m                11641      148351.06
# 33      c_6714   1968   f                 4116       68427.43
# 37      c_3454   1969   m                 3095       52016.33
# 527     c_4958   1999   m                 2433      135919.10
# 1098    c_8026   1978   m                  183        2424.50
# 2273    c_7421   1978   m                  178        2406.17
# 3095    c_5922   1977   m                  177        2216.32
# 3821    c_3263   1985   f                  177        2346.34
# 41      c_2595   1974   m                  176        2191.58
# 2301     c_760   1980   m                  176        2311.71

# %% [markdown]
# Nous voyons qu'il existe de très bons clients, et cela explique les grandes valeurs obtenus 41 et 42 ans avec le client c_1609, 52 et 53 ans avec les clients c_6714 et c_3454 et 22 ans avec le client c_4958.
#
# De plus, ces 4 clients, ont les plus hauts montants de livres achetés. En faisant les tests de corrélation, il serait utile d'écarter ces clients. Nous remarquons également que le client c_4958, avec un volume moindre, atteint un montant total assez élevé.
#
#
# Ainsi, nous allons également, vérifier l'impact de 4 clients sur les données.

# %%
f"Le Top 4 Client représente {df_transactions.drop_duplicates('client_id').sort_values(by='rang').head(4).sum()['nombre_livre_client'] / df_transactions.drop_duplicates('client_id')['nombre_livre_client'].sum()*100:0.2f} % des transactions"
# Out:
# 'Le Top 4 Client représente 6.86 % des transactions'

# %%
f"Le Top 4 Client représente {df_transactions.drop_duplicates('client_id').sort_values(by='rang').head(4).sum()['montant_total'] / df_transactions.drop_duplicates('client_id')['montant_total'].sum()*100:0.2f} % du montant des transactions"
# Out:
# 'Le Top 4 Client représente 7.49 % du montant des transactions'

# %% [markdown]
# #### DataFrame sans le top 4 clients

# %% [markdown]
# Nous créons un nouveau dataFrame sans le top 4 clients

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions[df_transactions['rang'] > 4]['birth'], axlabel='Birth from average clients - Transaction', kde=False, bins=76, ax=axes[0, 0])
sns.distplot(df_transactions[df_transactions['rang'] > 4]['age'], axlabel='Age from average clients - Transaction', kde=False, bins=76, ax=axes[0, 1])
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['birth'], axlabel='Birth from average clients - Transaction unique', kde=False, bins=76, ax=axes[1, 0])
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['age'], axlabel='Age from average clients - Transaction unique', kde=False, bins=76, ax=axes[1, 1])

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.distplot(df_transactions[df_transactions['rang'] > 4]['cat_age'], axlabel='Cat_age from average clients - Transaction', kde=False, bins=3, ax=axes[0])
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['cat_age'], axlabel='Cat_age from average clients - Transaction Unique', kde=False, bins=3, ax=axes[1])

# %% [markdown]
# Nous voyons ici, que la catégorie d'age des 30/49 ans est la plus représentative.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.countplot(df_transactions[df_transactions['rang'] > 4]['sex'], ax=axes[0])
sns.countplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['sex'], ax=axes[1])

# %% [markdown]
# L'écart est plus même sans le Top 4 Client

# %% [markdown]
# ### B. Colonne *price*, *cat_price* et *categ*

# %% [markdown]
# #### DataFrame avec tous les clients

# %% [markdown]
# Nous allons étudier la colonne *price* et *categ*. Nous allons déterminer si il existe une corrélation entre les deux. Les prix s'échalonne de 0.62 euros à 300 euros. Il existe 3 catégories dans *categ*

# %% [markdown]
# D'abord, nous allons regarder la colonne *price*, et la comparer avec la même colonne du fichier *products*

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions['price'], axlabel='Price - Transaction', color="skyblue", kde=False, bins=50, ax=axes[0, 0])
sns.distplot(df_transactions[df_transactions['price'] < 70]['price'], axlabel='Price 0 à 70 - Transaction', color="skyblue", kde=False, bins=70, ax=axes[0, 1])
sns.distplot(products['price'], axlabel='Price - Product', color="red", kde=False, ax=axes[1, 0])
sns.distplot(products[products['price'] < 70]['price'], axlabel='Price 0 à 70 - Product', color="red", kde=False, bins=35, ax=axes[1, 1])

# %% [markdown]
# Nous remarquons que la répartition des prix entre la référence produit et la commande des produits est différente. Cette différence est plus marqué sur des prix inférieur à 70 euros. Ce sont les livres entre 10 et 12 euros qui sont les plus vendus. Ensuite, la fourchette entre 6 et 18 euros représente la majorité des ventes.

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 10))
sns.distplot(df_transactions['cat_price'], axlabel='Cat_price - Transaction', color="skyblue", kde=False, bins=3)

# %% [markdown]
# La colonne *cat_price* nous montre également que la catégorie de livre la plus vendue est celle dont le prix est situé entre 10 et 19.99 euros.

# %% [markdown]
# Nous allons regarder la colonne *categ*, et essaye de comprendre ce qu'elle représente

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
products.groupby('categ').price.hist(ax=axes[0])
df_transactions.groupby('categ').price.hist(ax=axes[1])
# Out:
# categ
# 0    AxesSubplot(0.547727,0.125;0.352273x0.755)
# 1    AxesSubplot(0.547727,0.125;0.352273x0.755)
# 2    AxesSubplot(0.547727,0.125;0.352273x0.755)
# Name: price, dtype: object

# %% [markdown]
# Nous constatons que *categ* est sensible au prix mais doit représenter des types de livres différents, par exemple, la catégorie 1 représente les livres de poche, la catégorie 2, le livre grand format, et la catégorie 3 les beaux livres comme les encyclopédies.

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 10))
sns.boxplot(x=df_transactions['categ'], y=df_transactions['price'],data=df_transactions)

# %% [markdown]
# Nous constatons que les prix de *categ* sont dans un interquartile Q1-Q3 très petit, avec des bornes peu étendue également. Pour les categ 1 et 2, les outliers sont peu étalés, tandis que sur la categ 3, les outliers sont très étalés avec des prix élevés. Il y a une échalonnage des prix qui est plus marqué pour la categ 3.

# %% [markdown]
# #### DataFrame sans le top 4 clients

# %%
fig, axes = plt.subplots(3, 2, figsize=(20, 15))
sns.distplot(df_transactions[df_transactions['rang'] > 4]['price'], axlabel='Price from average clients - Transaction', color="skyblue", kde=False, bins=50, ax=axes[0, 0])
sns.distplot(df_transactions[(df_transactions['price'] < 70) & (df_transactions['rang'] > 4)]['price'], axlabel='Price 0 à 70 from average clients - Transaction', color="skyblue", kde=False, bins=35, ax=axes[0, 1])
sns.distplot(df_transactions[df_transactions['rang'] < 5]['price'], axlabel='Price from Top 4 Clients - Transaction', color="skyblue", kde=False, bins=50, ax=axes[1, 0])
sns.distplot(df_transactions[(df_transactions['price'] < 70) & (df_transactions['rang'] < 5)]['price'], axlabel='Price 0 à 70 from Top 4 Clients - Transaction', color="skyblue", kde=False, bins=35, ax=axes[1, 1])
sns.distplot(products['price'], axlabel='Price - Product', color="red", kde=False, ax=axes[2, 0])
sns.distplot(products[products['price'] < 70]['price'], axlabel='Price 0 à 70 - Product', color="red", kde=False, bins=35, ax=axes[2, 1])

# %% [markdown]
# Nous remarquons que la différence des formes de la courbe des prix des produits achetés par le top 4 des clients ou les clients normaux n'est pas significative.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x=df_transactions[df_transactions['rang'] > 4]['categ'], y=df_transactions['price'],data=df_transactions, ax=axes[0])
sns.boxplot(x=df_transactions[df_transactions['rang'] < 5]['categ'], y=df_transactions['price'],data=df_transactions, ax=axes[1])

# %% [markdown]
# Nous constatons que les deux graphiques sont semblables

# %% [markdown]
# ### C. Colonne *date*, *weekday*, *daytime*, *month*, *week*, *year*

# %% [markdown]
# #### DataFrame avec tous les clients

# %% [markdown]
# Nous allons vérifier les colonnes liés aux dates

# %%
df_transactions['date'].hist(bins = 12)

# %%
df_transactions.nlargest(1, 'date').date
# Out:
# 254695   2022-02-28 23:59:58.040472
# Name: date, dtype: datetime64[ns]

# %%
df_transactions.nsmallest(1, 'date').date
# Out:
# 221790   2021-03-01 00:01:07.843138
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Nous constatons bien que les dates débutent en mars 2021 et finissent fin février 2022, soit sur 12 mois

# %%
f, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions['weekday'], color="skyblue", kde=False, bins=7, ax=axes[0, 0])
sns.distplot(df_transactions['daytime'], color="red", kde=False, bins=24, ax=axes[0, 1])
sns.distplot(df_transactions['month'], color="olive", kde=False, bins=12, ax=axes[1, 0])
sns.distplot(df_transactions['week'], color="teal", kde=False, bins=52, ax=axes[1, 1])

# %% [markdown]
# Tout d'abord, il existe de moments dans l'année où le volume de vents est plus important. En septembre, à la rentrée, et en novembre et décembre, pendant les fêtes de fin d'année. Nous remarquons, également, que le jour de la semaine et l'heure d'achat non pas d'influence sur le volume de vente.
#
#
# Nous allons investiger sur les pics de ventes, mais aussi sur l'influence des jours de la semaine et de l'heure. Egalement, le mois d'octobre est vide, puisque nous l'avons enlever les données qui étaient erronées.

# %% [markdown]
# Tout d'abord, nous allons prendre un échantillion de 1 %

# %%
df_transactions_sample = df_transactions.sample(3367)

# %%
f, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions_sample['weekday'], axlabel='Sample - Weekday', color="skyblue", kde=False, bins=7, ax=axes[0, 0])
sns.distplot(df_transactions_sample['daytime'], axlabel='Sample - Daytime', color="red", kde=False, bins=24, ax=axes[0, 1])
sns.distplot(df_transactions_sample['month'], axlabel='Sample - Month', color="olive", kde=False, bins=12, ax=axes[1, 0])
sns.distplot(df_transactions_sample['week'], axlabel='Sample - Week', color="teal", kde=False, bins=52, ax=axes[1, 1])

# %% [markdown]
# Nous remarquons qu'avec un échantillon de 1 %, la représentation des graphiques est similaire. Egalement, le mois d'octobre est vide, puisque nous l'avons enlever les données qui étaient erronées.

# %% [markdown]
# #### DataFrame sans le top 4 clients

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
df_transactions[df_transactions['rang'] > 4]['date'].hist(bins = 12, ax=axes[0])
df_transactions[df_transactions['rang'] < 5]['date'].hist(bins = 12, ax=axes[1])

# %% [markdown]
# La répartition dans le temps entre les *average* clients et le top 4 est similaire

# %%
f, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions[df_transactions['rang'] > 4]['weekday'], axlabel='Average Client - Weekday', color="skyblue", kde=False, bins=7, ax=axes[0, 0])
sns.distplot(df_transactions[df_transactions['rang'] > 4]['daytime'], axlabel='Average Client - Daytime', color="red", kde=False, bins=24, ax=axes[0, 1])
sns.distplot(df_transactions[df_transactions['rang'] > 4]['month'], axlabel='Average Client - Month', color="olive", kde=False, bins=12, ax=axes[1, 0])
sns.distplot(df_transactions[df_transactions['rang'] > 4]['week'], axlabel='Average Client - Week', color="teal", kde=False, bins=52, ax=axes[1, 1])

# %%
f, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions[df_transactions['rang'] < 5]['weekday'], axlabel='Top 4 Client - Weekday', color="skyblue", kde=False, bins=7, ax=axes[0, 0])
sns.distplot(df_transactions[df_transactions['rang'] < 5]['daytime'], axlabel='Top 4 Client - Daytime', color="red", kde=False, bins=24, ax=axes[0, 1])
sns.distplot(df_transactions[df_transactions['rang'] < 5]['month'], axlabel='Top 4 Client - Month', color="olive", kde=False, bins=12, ax=axes[1, 0])
sns.distplot(df_transactions[df_transactions['rang'] < 5]['week'], axlabel='Top 4 Client - Week', color="teal", kde=False, bins=52, ax=axes[1, 1])

# %% [markdown]
# Nous constatons que le Top 4 Client n'a pas une influence significative sur la répartition des achats dans la semaine ou dans la journée. Egalement, le mois d'octobre est vide, puisque nous l'avons enlever les données qui étaient erronées.

# %% [markdown]
# ### D. Colonne *session_amount*, *session_nb_produit*  et *session_categ*

# %% [markdown]
# #### DataFrame avec tous les clients

# %%
f, axes = plt.subplots(1, 3, figsize=(20, 5))
sns.distplot(df_transactions.drop_duplicates('session_id')['session_amount'], color="skyblue", kde=False, bins=27, ax=axes[0])
sns.distplot(df_transactions.drop_duplicates('session_id')['session_nb_produit'], color="red", kde=False, bins=14, ax=axes[1])
sns.distplot(df_transactions.drop_duplicates('session_id')['session_categ'], color="olive", kde=False, bins=24, ax=axes[2])

# %% [markdown]
# Les paniers sont d'un montant entre 0.69 et 40 euros.

# %% [markdown]
# #### DataFrame sans le top 4 clients

# %%
f, axes = plt.subplots(2, 3, figsize=(20, 10))
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['session_amount'], axlabel='Average Client - Montant Session', color="skyblue", kde=False, bins=27, ax=axes[0, 0])
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['session_nb_produit'], axlabel='Average Client - Nb Produit par Session', color="red", kde=False, bins=14, ax=axes[0, 1])
sns.distplot(df_transactions[df_transactions['rang'] > 4].drop_duplicates('session_id')['session_categ'], axlabel='Average Client - Moyenne Categ par Session', color="olive", kde=False, bins=24, ax=axes[0, 2])
sns.distplot(df_transactions[df_transactions['rang'] < 5].drop_duplicates('session_id')['session_amount'], axlabel='Top 4 Client - Montant Session', color="skyblue", kde=False, bins=27, ax=axes[1, 0])
sns.distplot(df_transactions[df_transactions['rang'] < 5].drop_duplicates('session_id')['session_nb_produit'], axlabel='Top 4 Client - Nb Produit par Session', color="red", kde=False, bins=14, ax=axes[1, 1])
sns.distplot(df_transactions[df_transactions['rang'] < 5].drop_duplicates('session_id')['session_categ'], axlabel='Top 4 Client - Moyenne Categ par Session', color="olive", kde=False, bins=24, ax=axes[1, 2])

# %% [markdown]
# ### E. Conclusion

# %% [markdown]
# Nous avons 4 gros clients qui représentent plus de 7 % du montant des transactions et plus de 6 % du total des transactions, ils ont malgré tout, peu d'influence sur le profil des ventes. Néanmoins, nous approfondirons cela dans la 5e partie, pour essayer de determiner le profil de ces clients.
#
#
# Les principaux clients sont dans la tranche 30 - 49 ans. Après cette age, nous avons des clients ponctuels effectuant un achat souvent unique, qui semblent peu familiers avec des achats sur internet. En dessous de 30 ans, nous avons peu de clients, alors qu'ils sont généralement lecteurs, et plus connectés à Internet. Ce point devra être developpé afin de determiner les causes.
#
#
# Les livres les plus vendus sont dans une fourchette de 10 et 12 euros, la majorité des ventes de livres étant entre 6 et 18 euros. Nous allons analyser ces données pour conaaître les produits les plus vendus, ainsi que la répartition par *categ*
#
#
# Finalement, nous avons constaté que l'heure et le jour d'achat n'avaient pas d'influence sur le volume des ventes. Par contre, il existe deux périodes, Septembre / Octobre et Novembre / Décembre, où les ventes s'écartent de la moyenne annuelle. Nous allons, également, tâcher de comprendre les raisons de ces écarts.

# %% [markdown]
# ## 5. Analyses des données

# %% [markdown]
# ### A. Produits les plus vendus

# %% [markdown]
# #### Les livres les plus vendus en terme de prix et de volume

# %%
df_transactions[['id_prod', 'price', 'categ', 'book_total_price', 'book_rank_price', 'book_total_sold', 'book_rank_sold']].drop_duplicates('id_prod').nsmallest(10, 'book_rank_price')
# Out:
#        id_prod   price  categ  book_total_price  book_rank_price  \
# 208941   2_135   68.99      2          31873.38              1.0
# 258071   2_112   67.57      2          29122.67              2.0
# 85602    2_102   59.14      2          26967.84              3.0
# 175620   2_209   69.99      2          25616.34              4.0
# 5983     1_369   23.99      1          25429.40              5.0
# 22646    1_395   28.99      1          25047.36              6.0
# 295684   2_110   62.25      2          24962.25              7.0
# 149245   1_383   28.99      1          24206.65              8.0
# 299693   2_166  230.04      2          23924.16              9.0
# 57470    1_414   23.83      1          23782.34             10.0
#
#         book_total_sold  book_rank_sold
# 208941              462           141.5
# 258071              431           172.0
# 85602               456           149.0
# 175620              366           240.0
# 5983               1060             1.0
# ...

# %% [markdown]
# #### Les livres les plus vendus en terme de volume

# %%
df_transactions[['id_prod', 'price', 'categ', 'cat_age', 'book_total_price', 'book_rank_price', 'book_total_sold', 'book_rank_sold']].drop_duplicates('id_prod').nsmallest(100, 'book_rank_sold')['cat_age'].value_counts()
# Out:
# 2    90
# 3     6
# 1     4
# Name: cat_age, dtype: int64

# %% [markdown]
# Pour cette partie, nous allons prendre l'ancien Data Frame pour mettre en évidence le volume de vente nulle de *categ* 1 en Octobre.

# %%
df_transactions_old[['id_prod','price']].groupby('id_prod').count().nlargest(10, 'price')
# Out:
#          price
# id_prod
# 1_369     1081
# 1_417     1062
# 1_498     1036
# 1_414     1027
# 1_425     1013
# 1_398      952
# 1_406      946
# 1_413      944
# 1_403      939
# 1_407      933

# %%
bestProduct = df_transactions_old.groupby('id_prod').count().nlargest(10, 'price').index
df_transactions_best_product = df_transactions_old[df_transactions_old['id_prod'].isin(bestProduct)]
df_transactions_best_product[['id_prod', 'price', 'categ']].drop_duplicates('id_prod')
# Out:
#        id_prod  price  categ
# 2073     1_407  15.99      1
# 6509     1_369  23.99      1
# 36122    1_403  17.99      1
# 49351    1_413  17.99      1
# 62012    1_414  23.83      1
# 70003    1_417  20.99      1
# 74517    1_398  10.17      1
# 103857   1_498  23.37      1
# 113812   1_406  24.81      1
# 143520   1_425  16.99      1

# %% [markdown]
# Les 10 produits les plus vendus font tous partie de la *categ* 1, avec un prix variant de 10.17 à 24.81. Le premier livre d'une autre *categ* est en 43ème position.

# %%
f, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df_transactions_best_product['weekday'], axlabel='Best Product - Weekday', color="skyblue", kde=False, bins=7, ax=axes[0, 0])
sns.distplot(df_transactions_best_product['daytime'], axlabel='Best Product - Daytime', color="red", kde=False, bins=24, ax=axes[0, 1])
sns.distplot(df_transactions_best_product['month'], axlabel='Best Product - Month', color="olive", kde=False, bins=12, ax=axes[1, 0])
sns.distplot(df_transactions_best_product['week'], axlabel='Best Product - Week', color="teal", kde=False, bins=52, ax=axes[1, 1])

# %% [markdown]
# Nous remarquons, dans le dernier graphique, qu'il n'y a pas eu de ventes pendant 3 semaines en Octobre. Est-ce simplement les meilleurs produits, ou cela s'étends sur d'autres produits ?

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 15))
for i in range(9):
    j = i + 1
    df = df_transactions_old[df_transactions_old['id_prod'].isin(df_transactions_old.groupby('id_prod').count().nlargest(j * 10, 'price').index)]
    sns.distplot(df['week'], axlabel=f'Best Product 0 to {j * 10} - Week', color="skyblue", kde=False, bins=52, ax=axes[i//3, i%3])

# %% [markdown]
# Nous voyons que progrssivement, à partir du 40e produit, nous avons de nouveau des ventes en prendant ces trois semaines en Octobre. Nous allons regarder cette période.

# %%
df_transactions_old[df_transactions_old['week'].between(40, 42)].drop_duplicates('id_prod').describe()
# Out:
#              birth        price        categ          age      weekday  \
# count  1736.000000  1736.000000  1736.000000  1736.000000  1736.000000
# mean   1979.790899    17.429487     0.156682    41.209101     3.166475
# std      10.291573    26.712932     0.537570    10.291573     1.988568
# min    1931.000000     0.620000     0.000000    17.000000     0.000000
# 25%    1975.000000     6.250000     0.000000    35.000000     1.000000
# 50%    1980.000000    10.990000     0.000000    41.000000     3.000000
# 75%    1986.000000    16.052500     0.000000    46.000000     5.000000
# max    2004.000000   247.220000     2.000000    90.000000     6.000000
#
#            daytime   month         week    year
# count  1736.000000  1736.0  1736.000000  1736.0
# mean     11.421083    10.0    40.985023  2021.0
# std       7.030243     0.0     0.804028     0.0
# min       0.000000    10.0    40.000000  2021.0
# 25%       5.000000    10.0    40.000000  2021.0
# ...

# %% [markdown]
# Nous allons calculer le pourcentage de produits vendu par rapport à la moyenne habituelle.

# %%
sell_product = []
for i in range (1, 52):
    sell_product.append(df_transactions_old[df_transactions_old['week'].between(i, i+2)].drop_duplicates('id_prod').shape[0] / products.count()['id_prod'] * 100)
    
moy_product = np.mean(sell_product)

# %%
f"Nous avons vendu seulement {(df_transactions_old[df_transactions_old['week'].between(40, 42)].drop_duplicates('id_prod').shape[0]) / products.count()['id_prod'] * 100:0.2f} % de l'ensemble des produits présents sur le site au lieu de {moy_product:0.2f} %"
# Out:
# "Nous avons vendu seulement 52.83 % de l'ensemble des produits présents sur le site au lieu de 67.82 %"

# %%
df = df_transactions_old[df_transactions_old['week'].between(40, 42)].drop_duplicates('id_prod')

fig, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.distplot(df['price'], axlabel='Prix des produits vendus entre la semaine 40 et 42', color="skyblue", kde=False, bins=25, ax=axes[0, 0])
sns.distplot(df['categ'], axlabel='Categ des produits vendus entre la semaine 40 et 42', color="red", kde=False, bins=50, ax=axes[0, 1])
sns.distplot(df['weekday'], axlabel='Jour des produits vendus entre la semaine 40 et 42', color="olive", kde=False, bins=7, ax=axes[1, 0])
sns.distplot(df['daytime'], axlabel='Heure des produits vendus entre la semaine 40 et 42', color="teal", kde=False, bins=24, ax=axes[1, 1])

# %% [markdown]
# Nous remarquons qu'aucun livre de *categ* 1 n'a été vendu durant cette période. Est-ce une erreur ? Nous allons comparer le pourcentage de vente de *categ* 1 sur l'année et le comparer à la différence sur cette période.

# %%
sell_product = []
sell_product_categ_0 = []
sell_product_categ_1 = []
sell_product_categ_2 = []

for i in range (1, 53):
    sell_product.append(df_transactions_old[(df_transactions_old['week'] == i)].drop_duplicates('id_prod').shape[0] / products.count()['id_prod'] * 100)
    sell_product_categ_0.append(df_transactions_old[(df_transactions_old['week'] == i) & (df_transactions_old['categ'] == 0)].shape[0] / df_transactions_old[df_transactions_old['week'] == i].count()['id_prod'] * 100)
    sell_product_categ_1.append(df_transactions_old[(df_transactions_old['week'] == i) & (df_transactions_old['categ'] == 1)].shape[0] / df_transactions_old[df_transactions_old['week'] == i].count()['id_prod'] * 100)
    sell_product_categ_2.append(df_transactions_old[(df_transactions_old['week'] == i) & (df_transactions_old['categ'] == 2)].shape[0] / df_transactions_old[df_transactions_old['week'] == i].count()['id_prod'] * 100)
    
moy_product = np.mean(sell_product_categ_1)

# %%
x = pd.Series(range(1,53))

fig, axes = plt.subplots(3, 1, figsize=(20, 15))
sns.barplot(x=x, y=pd.Series(sell_product_categ_0), color="skyblue", ax=axes[0])
sns.barplot(x=x, y=pd.Series(sell_product_categ_1), color="skyblue", ax=axes[1])
sns.barplot(x=x, y=pd.Series(sell_product_categ_2), color="skyblue", ax=axes[2])

# %% [markdown]
# Nous constatons bien le fait qu'il n'y ai pas eu de vente durant les semaines 40 à 42, et un volume plus faible durant les semaines 39 et 43. Ainsi, pour garder un data Frame homogène, nous avons enlever ses 5 semaines.

# %% [markdown]
# Nous allons reprendre notre Data Frame corrigé pour reprendre l'analyse des données

# %% [markdown]
# #### Analyse par rapport l'age des acheteurs

# %% [markdown]
# ##### Pour tous les livres

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_age', y='book_total_sold',data=df_transactions, hue= 'sex', ax=axes[0])
sns.boxplot(x='cat_age', y='book_total_price',data=df_transactions, hue= 'sex', ax=axes[1])

# %% [markdown]
# Nous constatons que, pour le volume d'age, les quantité sont sensiblement les même pour chaque catégorie d'age. Par contre, nous voyons que la catégorie d'age des moins de 30 ans ont une dispersion et une médiane plus grande que les autres catégorie pour le montant dépensé.

# %% [markdown]
# ##### Pour le top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_age', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[0])
sns.boxplot(x='cat_age', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[1])

# %% [markdown]
# Nous voyons que la catégorie d'age intermédiaire a une dispersion et une médiane plus petite que les autres catégorie pour le montant dépensé et le volume acheté pour les livres les plus achetés

# %% [markdown]
# ##### Pour les livres autres que le Top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_age', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[0])
sns.boxplot(x='cat_age', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[1])

# %% [markdown]
# Nous voyons que la catégorie d'age des moins de 30 ans a une dispersion et une médiane plus grande que les autres catégorie pour le montant dépensé pour les autres livres que ceux du Top 100.

# %% [markdown]
# ##### Avec et sans les Top 4 Clients pour tous les livres

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))
sns.boxplot(x='cat_age', y='book_total_sold',data=df_transactions[df_transactions['rang'] > 4], hue='sex', ax=axes[0, 0])
sns.boxplot(x='cat_age', y='book_total_price',data=df_transactions[df_transactions['rang'] > 4], hue='sex', ax=axes[0, 1])
sns.boxplot(x='cat_age', y='book_total_sold',data=df_transactions[df_transactions['rang'] < 5], hue='sex', ax=axes[1, 0])
sns.boxplot(x='cat_age', y='book_total_price',data=df_transactions[df_transactions['rang'] < 5], hue='sex', ax=axes[1, 1])

# %% [markdown]
# Nous retrouvons la même représentations des acheteurs avec ou sans le Top 4 clients. De plus, ces clients se comportent de la même façon que leur categorie d'age.

# %% [markdown]
# ##### Avec et sans les Top 4 Clients pour le Top 100

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))
sns.boxplot(x='cat_age', y='book_total_sold', data=df_transactions[(df_transactions['rang'] > 4) & (df_transactions['book_rank_sold'] < 101)], hue= 'sex', ax=axes[0, 0])
sns.boxplot(x='cat_age', y='book_total_price', data=df_transactions[(df_transactions['rang'] > 4) & (df_transactions['book_rank_sold'] < 101)], hue= 'sex', ax=axes[0, 1])
sns.boxplot(x='cat_age', y='book_total_sold', data=df_transactions[(df_transactions['rang'] < 5) & (df_transactions['book_rank_sold'] < 101)], hue= 'sex', ax=axes[1, 0])
sns.boxplot(x='cat_age', y='book_total_price', data=df_transactions[(df_transactions['rang'] < 5) & (df_transactions['book_rank_sold'] < 101)], hue= 'sex', ax=axes[1, 1])

# %% [markdown]
# Nous retrouvons la même représentations des acheteurs avec ou sans le Top 4 clients.

# %% [markdown]
# ##### Avec et sans les Top 4 Clients pour les livres autres que le Top 100

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))
sns.boxplot(x='cat_age', y='book_total_sold', data=df_transactions[(df_transactions['rang'] > 4) & (df_transactions['book_rank_sold'] > 100)], hue= 'sex', ax=axes[0, 0])
sns.boxplot(x='cat_age', y='book_total_price', data=df_transactions[(df_transactions['rang'] > 4) & (df_transactions['book_rank_sold'] > 100)], hue= 'sex', ax=axes[0, 1])
sns.boxplot(x='cat_age', y='book_total_sold', data=df_transactions[(df_transactions['rang'] < 5) & (df_transactions['book_rank_sold'] > 100)], hue= 'sex', ax=axes[1, 0])
sns.boxplot(x='cat_age', y='book_total_price', data=df_transactions[(df_transactions['rang'] < 5) & (df_transactions['book_rank_sold'] > 100)], hue= 'sex', ax=axes[1, 1])

# %% [markdown]
# Pour conclure, nous pouvons dire que la catégorie d'age n'a que peu d'influence sur le volume des ventes, mais que la catégorie d'age des moins de 30 ans avait une médiane de montant d'achat plus élevée que les autres catégories.

# %% [markdown]
# #### Analyse par rapport la catégorie des articles

# %% [markdown]
# ##### Pour tous les livres

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='categ', y='book_total_sold',data=df_transactions, hue='sex', ax=axes[0])
sns.boxplot(x='categ', y='book_total_price',data=df_transactions, hue='sex', ax=axes[1])

# %% [markdown]
# Nouc constatons que la dispersion est plus grande et la médiane plus élevée pour les livres de la *categ* 1 pour les volumes vendus. Sans surprise, pour les montants ce sont les livres de la *categ* 2 qui ont la plus grande dispersion.

# %% [markdown]
# ##### Pour le top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='categ', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[0])
sns.boxplot(x='categ', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[1])

# %% [markdown]
# Nous remarquons que la dispersion chez les hommes achetant la *categ* 1 du Top 100 des livres est plus grande pour les 50 % des montant des achats.

# %% [markdown]
# ##### Pour les livres autres que le Top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='categ', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[0])
sns.boxplot(x='categ', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[1])

# %% [markdown]
# Nous constatons que, pour les livres n'appartenant pas au Top 100, les comportements d'achat en volume sont les mêmes quel que soit la *categ*

# %% [markdown]
# #### Analyse par rapport aux achats

# %% [markdown]
# ##### Pour tous les livres

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_nb_achat', y='book_total_sold',data=df_transactions, hue='sex', ax=axes[0])
sns.boxplot(x='cat_nb_achat', y='book_total_price',data=df_transactions, hue='sex', ax=axes[1])

# %% [markdown]
# Les comportement d'achat sont les mêmes quel que soit le nombre de sessions des clients. Il semble que la médiane des clients ayant le moins de session est plus élevée que les autres catégories.

# %% [markdown]
# ##### Pour le top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_nb_achat', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[0])
sns.boxplot(x='cat_nb_achat', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] < 101], hue='sex', ax=axes[1])

# %% [markdown]
# Les comportement d'achat sont les mêmes quel que soit le nombre de sessions des clients pour le top 100 des livres

# %% [markdown]
# ##### Pour les livres autres que le Top 100

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x='cat_nb_achat', y='book_total_sold',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[0])
sns.boxplot(x='cat_nb_achat', y='book_total_price',data=df_transactions[df_transactions['book_rank_sold'] > 100], hue='sex', ax=axes[1])

# %% [markdown]
# Les comportement d'achat sont les mêmes quel que soit le nombre de sessions des clients pour les livres autre que le top 100.

# %% [markdown]
# ### B. Les meilleurs clients

# %% [markdown]
# #### Analyse par rapport l'age des acheteurs

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))
sns.boxplot(x='cat_age', y='montant_total',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[0, 0])
sns.boxplot(x='cat_age', y='session_amount',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[0, 1])
sns.boxplot(x='cat_age', y='nombre_livre_client',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[1, 0])
sns.boxplot(x='cat_age', y='nombre_achat_client',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[1, 1])

# %% [markdown]
# Nous constatons que la catégorie d'age intermédiaire, sans le Top 4 client, a une médiane la plus élevée pour les achats totaux, le nombre de livre acheté et le nombre de livre par client, alors que les moins de 30 ans ont une médiane pour le montant de panier plus élevée.

# %%
sns.relplot(x="age", y="session_amount", size="montant_total",
            sizes=(40, 400), alpha=1, hue='categ', palette="muted",
            height=6, data=df_transactions[(df_transactions['rang'] > 4)].sample(200))
sns.relplot(x="age", y="nombre_livre_client", size="session_nb_produit",
            sizes=(40, 400), alpha=1, hue='categ', palette="muted",
            height=6, data=df_transactions[(df_transactions['rang'] > 4)].sample(200))
sns.relplot(x="age", y="freq_achat_mean", size="session_nb_produit_mean",
            sizes=(40, 400), alpha=1, hue='categ', palette="muted",
            height=6, data=df_transactions[(df_transactions['rang'] > 4)].sample(200))

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))
sns.boxplot(x='categ', y='montant_total',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[0, 0])
sns.boxplot(x='categ', y='session_amount',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[0, 1])
sns.boxplot(x='categ', y='nombre_livre_client',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[1, 0])
sns.boxplot(x='categ', y='nombre_achat_client',data=df_transactions[(df_transactions['rang'] > 4)], hue= 'sex', ax=axes[1, 1])

# %%
sns.jointplot(x='age', y='nombre_livre_client', kind="hex", data = df_transactions[(df_transactions['rang'] > 4)])

# %%
sns.jointplot(x="age", y="nombre_livre_client", data=df_transactions[(df_transactions['rang'] > 4)].sample(200), kind="kde");

# %%
corrmat = df_transactions[(df_transactions['rang'] > 4)].sample(200).corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
sns.relplot(x="session_amount", y="freq_achat_mean", hue = "categ", data = df_transactions[(df_transactions['rang'] > 4)].sample(200))

# %%
df_transactions.columns
# Out:
# Index(['id_prod', 'date', 'session_id', 'client_id', 'sex', 'birth', 'price',
#        'categ', 'age', 'cat_age', 'cat_price', 'weekday', 'daytime', 'month',
#        'week', 'year', 'session_amount', 'session_nb_produit', 'session_categ',
#        'nombre_achat_client', 'cat_nb_achat', 'nombre_livre_client',
#        'montant_total', 'rang', 'session_nb_produit_mean', 'categ_mean',
#        'freq_achat_mean', 'session_amount_mean', 'book_total_sold',
#        'book_rank_sold', 'book_total_price', 'book_rank_price'],
#       dtype='object')

# %%
counter = (df_transactions.groupby(['categ', 'week'])['id_prod'].count())
counter_0 = counter.xs(0)
counter_1 = counter.xs(1)
counter_2 = counter.xs(2)

fig, axes = plt.subplots(1, 1, figsize=(20, 5))
sns.lineplot(x=counter_0.index, y=counter_0.values)
sns.lineplot(x=counter_1.index, y=counter_1.values)
sns.lineplot(x=counter_2.index, y=counter_2.values)

# %%
counter_0
# Out:
# week
# 1     3754
# 2     3570
# 3     3301
# 4     3260
# 5     3821
# 6     4273
# 7     4400
# 8     4545
# 9     4778
# 10    4168
# 11    4085
# 12    3996
# 13    4155
# 14    4466
# 15    4458
# 16    4575
# 17    4626
# 18    4314
# 19    4102
# 20    4095
# 21    4167
# 22    3861
# 23    3730
# 24    3719
# 25    3638
# 26    3369
# 27    3160
# 28    3090
# 29    2905
# 30    3007
# 31    3384
# 32    3471
# 33    3644
# 34    3675
# 35    4230
# 36    4910
# 37    5423
# 38    5959
# 44    3619
# 45    3577
# 46    3355
# 47    3156
# 48    3613
# 49    4112
# 50    4363
# 51    4545
# 52    4593
# Name: id_prod, dtype: int64

# %%
df_transactions
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   f   1977
# 1       0_1483 2021-12-27 11:11:12.123067   s_140787    c_5433   f   1981
# 2       0_1483 2021-07-04 06:43:45.676567    s_57626    c_3679   f   1989
# 3       0_1483 2021-09-19 08:45:43.735331    s_92165    c_1609   m   1980
# 4       0_1483 2021-07-22 20:45:15.286364    s_65805    c_1609   m   1980
# ...        ...                        ...        ...       ...  ..    ...
# 310085    2_93 2022-01-13 07:55:08.588434   s_149109     c_497   m   1998
# 310086  0_1920 2021-04-13 18:36:10.252971    s_20115    c_7088   m   1987
# 310087  0_1920 2021-05-30 02:37:22.371278    s_41465    c_7748   f   1989
# 310088    2_28 2021-05-11 01:31:34.932056    s_32812    c_7613   f   1993
# 310089    2_98 2021-03-08 21:10:32.250919     s_3637    c_5967   f   2003
#
#          price  categ  age cat_age  ... montant_total    rang  \
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(x=df_transactions_best_product['cat_price'], y=df_transactions_best_product['price'],data=df_transactions_best_product, ax=axes[0])
sns.boxplot(x=df_transactions_best_product['categ'], y=df_transactions_best_product['price'],data=df_transactions_best_product, ax=axes[1])

# %%
fig, axes = plt.subplots(7, 2, figsize=(20, 70))
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['age'],data=df_transactions, ax=axes[0, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['age'],data=df_transactions, ax=axes[0, 1])
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['price'],data=df_transactions, ax=axes[1, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['price'],data=df_transactions, ax=axes[1, 1])
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['session_amount'],data=df_transactions, ax=axes[2, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['session_amount'],data=df_transactions, ax=axes[2, 1])
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['session_nb_produit'],data=df_transactions, ax=axes[3, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['session_nb_produit'],data=df_transactions, ax=axes[3, 1])
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['session_categ'],data=df_transactions, ax=axes[4, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['session_categ'],data=df_transactions, ax=axes[4, 1])
sns.boxplot(x=df_transactions['cat_price'], y=df_transactions['categ'],data=df_transactions, ax=axes[5, 0])
sns.boxplot(x=df_transactions['cat_age'], y=df_transactions['categ'],data=df_transactions, ax=axes[5, 1])
sns.boxplot(x=df_transactions['sex'], y=df_transactions['price'],data=df_transactions, ax=axes[6, 0])
sns.boxplot(x=df_transactions['sex'], y=df_transactions['age'],data=df_transactions, ax=axes[6, 1])

# %%
df_transactions
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   f   1977
# 1       0_1483 2021-12-27 11:11:12.123067   s_140787    c_5433   f   1981
# 2       0_1483 2021-07-04 06:43:45.676567    s_57626    c_3679   f   1989
# 3       0_1483 2021-09-19 08:45:43.735331    s_92165    c_1609   m   1980
# 4       0_1483 2021-07-22 20:45:15.286364    s_65805    c_1609   m   1980
# ...        ...                        ...        ...       ...  ..    ...
# 310085    2_93 2022-01-13 07:55:08.588434   s_149109     c_497   m   1998
# 310086  0_1920 2021-04-13 18:36:10.252971    s_20115    c_7088   m   1987
# 310087  0_1920 2021-05-30 02:37:22.371278    s_41465    c_7748   f   1989
# 310088    2_28 2021-05-11 01:31:34.932056    s_32812    c_7613   f   1993
# 310089    2_98 2021-03-08 21:10:32.250919     s_3637    c_5967   f   2003
#
#          price  categ  age cat_age  ... montant_total    rang  \
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.distplot(df_transactions_best_product['cat_age'], axlabel='Cat_age from average clients - Transaction', kde=False, bins=8, ax=axes[0])
sns.distplot(df_transactions_best_product.drop_duplicates('session_id')['cat_age'], axlabel='Cat_age from average clients - Transaction Unique', kde=False, bins=8, ax=axes[1])

# %%
df_transactions.drop_duplicates('session_id').groupby('cat_age').mean()['nombre_achat_client']
# Out:
# cat_age
# 1    163.863858
# 2    331.404130
# 3     27.080238
# Name: nombre_achat_client, dtype: float64

# %%
df_transactions[df_transactions['client_id'] == 'c_1609']
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 3       0_1483 2021-09-19 08:45:43.735331    s_92165    c_1609   m   1980
# 4       0_1483 2021-07-22 20:45:15.286364    s_65805    c_1609   m   1980
# 5       0_1483 2021-05-08 06:20:05.395325    s_31519    c_1609   m   1980
# 6       0_1483 2021-04-17 06:01:35.017859    s_21725    c_1609   m   1980
# 7       0_1483 2021-06-06 13:42:00.282408    s_44891    c_1609   m   1980
# ...        ...                        ...        ...       ...  ..    ...
# 291303   0_793 2021-09-04 18:29:16.065113    s_85062    c_1609   m   1980
# 291314   1_725 2021-09-22 22:22:12.619872    s_93931    c_1609   m   1980
# 291357   0_728 2021-05-19 23:50:05.092047    s_36827    c_1609   m   1980
# 291362   1_132 2021-07-23 10:26:51.125918    s_66067    c_1609   m   1980
# 291412   0_479 2021-11-23 06:41:59.849027   s_123736    c_1609   m   1980
#
#         price  categ  age cat_age  ... montant_total  rang  \
# ...

# %%
df_transactions_best_product[df_transactions_best_product['client_id'] == 'c_1609']
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 2079     1_407 2021-12-12 03:17:12.469234   s_133074    c_1609   m   1980
# 2080     1_407 2021-12-25 06:52:16.919924   s_139670    c_1609   m   1980
# 2081     1_407 2021-09-22 16:02:09.863450    s_93814    c_1609   m   1980
# 2082     1_407 2022-01-09 22:02:51.738637   s_147475    c_1609   m   1980
# 2083     1_407 2021-05-29 16:11:19.011667    s_41258    c_1609   m   1980
# ...        ...                        ...        ...       ...  ..    ...
# 143545   1_425 2021-12-23 14:43:18.602269   s_138807    c_1609   m   1980
# 143546   1_425 2021-06-18 01:43:56.894257    s_50130    c_1609   m   1980
# 143547   1_425 2022-01-11 12:12:47.830947   s_148232    c_1609   m   1980
# 143548   1_425 2021-03-18 11:46:41.408098     s_8025    c_1609   m   1980
# 143549   1_425 2021-05-08 05:07:20.027852    s_31495    c_1609   m   1980
#
#         price  categ  age cat_age cat_price  weekday  daytime  month  week  \
# ...
